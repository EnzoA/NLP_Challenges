# %% [markdown]
# ## Custom embeddings con Gensim

# %% [markdown]
# El objetivo de este notebook es utilizar documentos / corpus para crear embeddings de palabras. Se utilizará a la obra Crítica de la Razón Pura del filósofo Immanuel Kant para generar los embeddings. Se espera así que los vectores capten similitudes semánticas entre términos que son relevantes en el contexto de la obra de este pensador.

# %%
import string
import pandas as pd
import numpy as np

from keras.preprocessing.text import text_to_word_sequence

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from gensim.models.callbacks import CallbackAny2Vec
from gensim.models import Word2Vec

from sklearn.manifold import TSNE

import plotly.graph_objects as go
import plotly.express as px
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### 1 - Carga de datos y preprocesamiento

# %%
krv_df = pd.read_csv('https://www.gutenberg.org/cache/epub/4280/pg4280.txt', delimiter='\t')

sentence_tokens = []
# Recorrer todas las filas y transformar las oraciones.
for _, row in krv_df[:None].iterrows():
    sentence_tokens.append(text_to_word_sequence(row[0]))

# Renombrar la única columna del DF.
krv_df.rename(columns={ krv_df.columns[-1]: 'document' }, inplace=True)

# Explorar algunos de los tokens obtenidos.
print(f'Algunos tokens obtenidos: ', sentence_tokens[:2])

krv_df.head()
# Out:
# Algunos tokens obtenidos:  [['this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'united', 'states', 'and'], ['most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions']]
#                                             document
# 0  This ebook is for the use of anyone anywhere i...
# 1  most other parts of the world at no cost and w...
# 2  whatsoever. You may copy it, give it away or r...
# 3  of the Project Gutenberg License included with...
# 4  at www.gutenberg.org. If you are not located i...

# %% [markdown]
# ### 2 - Crear los vectores (word2vec)

# %%
class callback(CallbackAny2Vec):
    '''
    Callback to print loss after each epoch
    '''
    def __init__(self):
        self.epoch = 0

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()
        if self.epoch == 0:
            print('Loss after epoch {}: {}'.format(self.epoch, loss))
        elif self.epoch % 5 == 0:
            print('Loss after epoch {}: {}'.format(self.epoch, loss - self.loss_previous_step))
        self.epoch += 1
        self.loss_previous_step = loss

w2v_model = Word2Vec(min_count=5,
                     window=2,
                     vector_size=300,
                     negative=20,
                     workers=1,
                     sg=1) # modelo 0:CBOW  1:skipgram

# Obtener el vocabulario con los tokens.
w2v_model.build_vocab(sentence_tokens)

# Cantidad de filas/documentos encontradas en el corpus.
print('Cantidad de documentos en el corpus:', w2v_model.corpus_count)

# Cantidad de palabras encontradas en el corpus.
print('Cantidad de palabras distintas en el corpus:', len(w2v_model.wv.index_to_key))
# Out:
# Cantidad de documentos en el corpus: 19487
# Cantidad de palabras distintas en el corpus: 2342

# %% [markdown]
# ### 3 - Entrenar embeddings

# %%
w2v_model.train(sentence_tokens,
                total_examples=w2v_model.corpus_count,
                epochs=100,
                compute_loss=True,
                callbacks=[callback()])
# Out:
# Loss after epoch 0: 1410867.625
# Loss after epoch 5: 886133.0
# Loss after epoch 10: 812294.0
# Loss after epoch 15: 789826.0
# Loss after epoch 20: 737610.0
# Loss after epoch 25: 716918.0
# Loss after epoch 30: 709100.0
# Loss after epoch 35: 698432.0
# Loss after epoch 40: 692574.0
# Loss after epoch 45: 682076.0
# Loss after epoch 50: 673384.0
# Loss after epoch 55: 672116.0
# Loss after epoch 60: 669444.0
# Loss after epoch 65: 669588.0
# Loss after epoch 70: 660712.0
# Loss after epoch 75: 659900.0
# Loss after epoch 80: 655916.0
# Loss after epoch 85: 651424.0
# Loss after epoch 90: 654356.0
# Loss after epoch 95: 87768.0
# (13386059, 21294000)

# %% [markdown]
# ### 4 - Ensayar

# %%
def print_most_similars(model, word, topn):
    print(f'Palabras más similares a {word}:')
    for word, similarity in model.wv.most_similar(positive=[word], topn=topn):
        print(f'Palabra: {word}. Similitud: {similarity}')
    print('\n')

for word in ['space', 'time', 'reason', 'priori', 'posteriori', 'intuition', 'category', 'metaphysic', 'sensibility', 'necessary']:
    print_most_similars(w2v_model, word, 10)
# Out:
# Palabras más similares a space:
# Palabra: time. Similitud: 0.34406179189682007
# Palabra: shape. Similitud: 0.32885977625846863
# Palabra: filled. Similitud: 0.3281041979789734
# Palabra: ens. Similitud: 0.3260181248188019
# Palabra: void. Similitud: 0.319690078496933
# Palabra: contemporaneously. Similitud: 0.3093798756599426
# Palabra: intuition. Similitud: 0.30840423703193665
# Palabra: sensibility. Similitud: 0.30623307824134827
# Palabra: spaces. Similitud: 0.3056923449039459
# Palabra: antecede. Similitud: 0.30433782935142517
#
#
# Palabras más similares a time:
# Palabra: space. Similitud: 0.3440617322921753
# Palabra: fills. Similitud: 0.3110807538032532
# Palabra: unceasing. Similitud: 0.3078629672527313
# Palabra: succeeding. Similitud: 0.3045356869697571
# Palabra: intellect. Similitud: 0.3015232980251312
# Palabra: empiricism. Similitud: 0.2970053553581238
# Palabra: same. Similitud: 0.29621005058288574
# Palabra: intuited. Similitud: 0.2952442765235901
# Palabra: located. Similitud: 0.2916404604911804
# Palabra: past. Similitud: 0.28913506865501404
#
#
# Palabras más similares a reason:
# Palabra: reason—a. Similitud: 0.31824228167533875
# Palabra: reason—the. Similitud: 0.3178299069404602
# Palabra: appendix. Similitud: 0.29168596863746643
# Palabra: intellect. Similitud: 0.2748672366142273
# Palabra: impose. Similitud: 0.2717762589454651
# Palabra: illustrate. Similitud: 0.2701800465583801
# Palabra: inquire. Similitud: 0.26921212673187256
# Palabra: discipline. Similitud: 0.2669684588909149
# Palabra: specification. Similitud: 0.26488447189331055
# Palabra: thesis. Similitud: 0.2558768689632416
#
#
# Palabras más similares a priori:
# Palabra: à. Similitud: 0.6296603679656982
# Palabra: posteriori. Similitud: 0.39344313740730286
# Palabra: priori”. Similitud: 0.382986456155777
# Palabra: knowing. Similitud: 0.33028602600097656
# Palabra: “à. Similitud: 0.32731661200523376
# Palabra: qualities. Similitud: 0.3235935568809509
# Palabra: certitude. Similitud: 0.3166789710521698
# Palabra: tests. Similitud: 0.314130961894989
# Palabra: arriving. Similitud: 0.3140547573566437
# Palabra: cognizing. Similitud: 0.3107733428478241
#
#
# Palabras más similares a posteriori:
# Palabra: datum. Similitud: 0.39369893074035645
# Palabra: priori. Similitud: 0.3934430778026581
# Palabra: inferring. Similitud: 0.372678279876709
# Palabra: unconditionally. Similitud: 0.37083306908607483
# Palabra: ostensive. Similitud: 0.3698647618293762
# Palabra: qualities. Similitud: 0.3605533838272095
# Palabra: exhibited. Similitud: 0.3601372241973877
# Palabra: arrived. Similitud: 0.3588029742240906
# Palabra: progression. Similitud: 0.35695621371269226
# Palabra: intuited. Similitud: 0.3557337522506714
#
#
# Palabras más similares a intuition:
# Palabra: intuitions. Similitud: 0.3418821096420288
# Palabra: intuited. Similitud: 0.3339661657810211
# Palabra: representation. Similitud: 0.3333185315132141
# Palabra: consciousness. Similitud: 0.3215351104736328
# Palabra: sensuous. Similitud: 0.31827646493911743
# Palabra: additions. Similitud: 0.31429508328437805
# Palabra: internal. Similitud: 0.31254449486732483
# Palabra: space. Similitud: 0.3084043264389038
# Palabra: schematism. Similitud: 0.3072013258934021
# Palabra: abstract. Similitud: 0.30667823553085327
#
#
# Palabras más similares a category:
# Palabra: 16. Similitud: 0.33264079689979553
# Palabra: 22. Similitud: 0.3226684033870697
# Palabra: furnished. Similitud: 0.316855251789093
# Palabra: believes. Similitud: 0.3158399164676666
# Palabra: cogitates. Similitud: 0.30423492193222046
# Palabra: iii. Similitud: 0.30252230167388916
# Palabra: augment. Similitud: 0.30212733149528503
# Palabra: list. Similitud: 0.2948678433895111
# Palabra: genus. Similitud: 0.2947840392589569
# Palabra: logically. Similitud: 0.29345670342445374
#
#
# Palabras más similares a metaphysic:
# Palabra: ethics. Similitud: 0.4750704765319824
# Palabra: conflicts. Similitud: 0.39398691058158875
# Palabra: endless. Similitud: 0.3799764811992645
# Palabra: conceptus. Similitud: 0.37834933400154114
# Palabra: mechanism. Similitud: 0.3675253391265869
# Palabra: outward. Similitud: 0.3651620149612427
# Palabra: logic. Similitud: 0.3506735563278198
# Palabra: considers. Similitud: 0.3502579629421234
# Palabra: conflict. Similitud: 0.33997735381126404
# Palabra: physiology. Similitud: 0.33828431367874146
#
#
# Palabras más similares a sensibility:
# Palabra: impulses. Similitud: 0.33276867866516113
# Palabra: space. Similitud: 0.30623307824134827
# Palabra: cogitable. Similitud: 0.303122341632843
# Palabra: receptivity. Similitud: 0.2978084683418274
# Palabra: schematism. Similitud: 0.29690954089164734
# Palabra: sensuous. Similitud: 0.296732634305954
# Palabra: products. Similitud: 0.295779824256897
# Palabra: primitive. Similitud: 0.294242799282074
# Palabra: belonging. Similitud: 0.2919965386390686
# Palabra: old. Similitud: 0.29137280583381653
#
#
# Palabras más similares a necessary:
# Palabra: supposes. Similitud: 0.33216169476509094
# Palabra: unchangeable. Similitud: 0.3165537714958191
# Palabra: sensuously. Similitud: 0.30552569031715393
# Palabra: absolutely. Similitud: 0.3043499290943146
# Palabra: sub. Similitud: 0.30350813269615173
# Palabra: recognized. Similitud: 0.30070215463638306
# Palabra: practically. Similitud: 0.29169896245002747
# Palabra: eternal. Similitud: 0.29008036851882935
# Palabra: subsumed. Similitud: 0.28554579615592957
# Palabra: determinability. Similitud: 0.27949124574661255

# %%
def print_least_similars(model, word, topn):
    print(f'Palabras menos similares a {word}:')
    for word, similarity in model.wv.most_similar(negative=[word], topn=topn):
        print(f'Palabra: {word}. Similitud: {similarity}')
    print('\n')

for word in ['space', 'time', 'reason', 'priori', 'posteriori', 'intuition', 'category', 'metaphysic', 'sensibility', 'necessary']:
    print_least_similars(w2v_model, word, 10)
# Out:
# Palabras menos similares a space:
# Palabra: procedure. Similitud: 0.06896268576383591
# Palabra: employed. Similitud: 0.04209689050912857
# Palabra: categorical. Similitud: 0.0312868170440197
# Palabra: logicians. Similitud: 0.021014627069234848
# Palabra: philosophical. Similitud: 0.01958725042641163
# Palabra: cogitates. Similitud: 0.01919943280518055
# Palabra: man. Similitud: 0.013142800889909267
# Palabra: against. Similitud: 0.012682957574725151
# Palabra: added. Similitud: 0.012305451557040215
# Palabra: extending. Similitud: 0.012185166589915752
#
#
# Palabras menos similares a time:
# Palabra: help. Similitud: 0.03095529042184353
# Palabra: requirement. Similitud: 0.025061752647161484
# Palabra: hypotheses. Similitud: 0.02455754764378071
# Palabra: essential. Similitud: 0.019175544381141663
# Palabra: perfect. Similitud: 0.01153555791825056
# Palabra: establishes. Similitud: 0.009404866024851799
# Palabra: comparison. Similitud: 0.009064728394150734
# Palabra: introduction. Similitud: 0.004550703801214695
# Palabra: properly. Similitud: 0.003973528277128935
# Palabra: influence. Similitud: 0.001538703916594386
#
#
# Palabras menos similares a reason:
# Palabra: think. Similitud: 0.06593663990497589
# Palabra: full. Similitud: 0.030523130670189857
# Palabra: like. Similitud: 0.029416611418128014
# Palabra: having. Similitud: 0.02267877571284771
# Palabra: notions. Similitud: 0.01811814121901989
# Palabra: indicate. Similitud: 0.017906803637742996
# Palabra: subtle. Similitud: 0.011663650162518024
# Palabra: motion. Similitud: 0.01055903173983097
# Palabra: properties. Similitud: 0.010428961366415024
# Palabra: contained. Similitud: 0.00980091281235218
#
#
# Palabras menos similares a priori:
# Palabra: arranged. Similitud: 0.029463035985827446
# Palabra: great. Similitud: 0.02655869722366333
# Palabra: maintains. Similitud: 0.010912828147411346
# Palabra: long. Similitud: 0.00545605830848217
# Palabra: abstracted. Similitud: 0.005256183445453644
# Palabra: soon. Similitud: 0.0036177863366901875
# Palabra: preserve. Similitud: -0.0009310421883128583
# Palabra: assumption. Similitud: -0.003511471673846245
# Palabra: signs. Similitud: -0.005305745173245668
# Palabra: wise. Similitud: -0.005581719800829887
#
#
# Palabras menos similares a posteriori:
# Palabra: claim. Similitud: 0.06590498238801956
# Palabra: long. Similitud: 0.052046649158000946
# Palabra: provide. Similitud: 0.04273879528045654
# Palabra: soon. Similitud: 0.03507744148373604
# Palabra: deserves. Similitud: 0.03144579380750656
# Palabra: peace. Similitud: 0.03040856122970581
# Palabra: lose. Similitud: 0.024180427193641663
# Palabra: future. Similitud: 0.022790446877479553
# Palabra: whom. Similitud: 0.019096381962299347
# Palabra: adopt. Similitud: 0.011086606420576572
#
#
# Palabras menos similares a intuition:
# Palabra: “if. Similitud: 0.007983624935150146
# Palabra: causal. Similitud: 0.005256326869130135
# Palabra: makes. Similitud: 0.0007755942642688751
# Palabra: changeable. Similitud: -0.0026989527978003025
# Palabra: advisable. Similitud: -0.003889822866767645
# Palabra: full. Similitud: -0.004739349242299795
# Palabra: predicate. Similitud: -0.009068595245480537
# Palabra: grounds. Similitud: -0.010922374203801155
# Palabra: consists. Similitud: -0.01133778877556324
# Palabra: strictly. Similitud: -0.01155847404152155
#
#
# Palabras menos similares a category:
# Palabra: leave. Similitud: 0.1307498961687088
# Palabra: led. Similitud: 0.09626461565494537
# Palabra: dangerous. Similitud: 0.06021875888109207
# Palabra: institute. Similitud: 0.056518618017435074
# Palabra: proposed. Similitud: 0.049060702323913574
# Palabra: decide. Similitud: 0.0455021895468235
# Palabra: safe. Similitud: 0.0444190539419651
# Palabra: besides. Similitud: 0.03636994585394859
# Palabra: doctrines. Similitud: 0.03512777388095856
# Palabra: habit. Similitud: 0.03320492431521416
#
#
# Palabras menos similares a metaphysic:
# Palabra: almost. Similitud: 0.07385747879743576
# Palabra: out. Similitud: 0.06342529505491257
# Palabra: increase. Similitud: 0.05649079009890556
# Palabra: down. Similitud: 0.044554855674505234
# Palabra: better. Similitud: 0.03273908048868179
# Palabra: find. Similitud: 0.027812574058771133
# Palabra: expect. Similitud: 0.027176888659596443
# Palabra: draw. Similitud: 0.025802871212363243
# Palabra: distinct. Similitud: 0.02272692322731018
# Palabra: follow. Similitud: 0.02051064372062683
#
#
# Palabras menos similares a sensibility:
# Palabra: 5. Similitud: 0.05459285154938698
# Palabra: preserve. Similitud: 0.048918575048446655
# Palabra: maintaining. Similitud: 0.03706592321395874
# Palabra: stand. Similitud: 0.025238867849111557
# Palabra: proceeded. Similitud: 0.024946076795458794
# Palabra: admitted. Similitud: 0.018210211768746376
# Palabra: loss. Similitud: 0.01749906875193119
# Palabra: more. Similitud: 0.015793487429618835
# Palabra: greatest. Similitud: 0.015396278351545334
# Palabra: division. Similitud: 0.013593754731118679
#
#
# Palabras menos similares a necessary:
# Palabra: syllogisms. Similitud: 0.053756460547447205
# Palabra: apply. Similitud: 0.05024610087275505
# Palabra: shape. Similitud: 0.04058653861284256
# Palabra: works. Similitud: 0.028762798756361008
# Palabra: raised. Similitud: 0.026618391275405884
# Palabra: expose. Similitud: 0.010548820719122887
# Palabra: objections. Similitud: 0.008810479193925858
# Palabra: securely. Similitud: 0.005124551709741354
# Palabra: thinker. Similitud: 0.0031987738329917192
# Palabra: solve. Similitud: 0.0018519996665418148

# %% [markdown]
# ### 5 - Visualizar agrupación de vectores

# %%
def reduce_dimensions(model, num_dimensions=2):
    vectors = np.asarray(model.wv.vectors)
    labels = np.asarray(model.wv.index_to_key)

    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    return vectors, labels

# Graficar en 2D.
vecs, labels = reduce_dimensions(w2v_model)
MAX_WORDS = 100
fig = px.scatter(x=vecs[:MAX_WORDS, 0], y=vecs[:MAX_WORDS, 1], text=labels[:MAX_WORDS])
fig.show(renderer='colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c2ea6639-50de-41e3-8ebd-a986ff235bc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2ea6639-50de-41e3-8ebd-a986ff235bc1")) {                    Plotly.newPlot(                        "c2ea6639-50de-41e3-8ebd-a986ff235bc1",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["the","of","to","in","is","and","a","which","that","it","as","be","this","not","we","but","for","all","by","an","are","with","reason","from","or","its","only","i","can","conception","our","must","experience","pure","time","object","conceptions","have","if","understanding","on","no","other","these","at","may","itself","intuition","they","\u00e0","cannot","possible","empirical","priori","existence","phenomena","us","cognition","transcendental","so","given","has","objects","any","one","therefore","unity","being","such","nature","their","merely","without","things","necessary","relation","them","conditions","upon","thus","principles","means","there","space","would","consequently","world","principle","same","than","do","general","possibility","mere","condition","idea","case","series","nothing","because"],"x":[0.8378221392631531,0.8161247968673706,0.9877269268035889,0.96112060546875,1.1038204431533813,0.9266628623008728,1.0060514211654663,1.0651100873947144,1.0576107501983643,1.0407072305679321,1.1188676357269287,1.3241097927093506,0.9402555823326111,1.0974289178848267,0.9988333582878113,1.0763367414474487,0.9680795669555664,0.9128409624099731,1.0205506086349487,1.1966346502304077,1.011907935142517,0.9790968298912048,0.8992882370948792,1.0636646747589111,0.9375122785568237,0.8238813281059265,1.1497255563735962,2.0741939544677734,1.2285093069076538,1.1748377084732056,0.932686984539032,1.1868983507156372,1.4432547092437744,1.0190221071243286,1.2920606136322021,1.5435446500778198,1.5115388631820679,0.8674881458282471,1.0914422273635864,1.1028763055801392,4.1587443351745605,1.0517922639846802,1.0096484422683716,0.8093293309211731,0.809984028339386,1.1701864004135132,1.2262203693389893,1.6505088806152344,1.2823158502578735,3.631453037261963,1.239288568496704,1.3588461875915527,1.4909769296646118,3.6857330799102783,1.0768505334854126,1.2957520484924316,1.1477458477020264,1.2002583742141724,0.7360453605651855,1.0959330797195435,1.9371097087860107,0.9262450337409973,1.583911657333374,4.235116958618164,0.9438228607177734,1.2658957242965698,0.9936871528625488,1.2482911348342896,1.043863296508789,0.7303023934364319,0.5964345932006836,1.080850601196289,0.8997265696525574,1.0051467418670654,1.1366184949874878,1.2212882041931152,0.9933167695999146,1.2631267309188843,0.8320109248161316,0.8871937990188599,1.0477946996688843,1.4247771501541138,1.331555962562561,1.527862787246704,1.1888657808303833,1.3980165719985962,2.171307325363159,0.9940589666366577,0.7446785569190979,0.7753869891166687,0.9986361265182495,0.9910640716552734,0.8800125122070312,0.7984209060668945,1.3236799240112305,0.7974819540977478,1.03127121925354,1.7712527513504028,1.2922945022583008,1.1751065254211426],"xaxis":"x","y":[0.4057001769542694,0.5879698395729065,-0.06974782049655914,0.48999324440956116,0.4395969808101654,0.3879742920398712,0.5265972018241882,0.3939318060874939,0.2789762616157532,0.16037270426750183,0.45675793290138245,0.2762809097766876,0.2971647083759308,0.25464263558387756,0.03831109404563904,0.4238908290863037,0.2660745680332184,0.648781955242157,0.521475613117218,0.4265889525413513,0.6307851672172546,0.47948673367500305,0.06576583534479141,0.5375948548316956,0.5 ...

# %% [markdown]
# El gráfico da una idea intuitiva de cómo "space", por ejemplo, está relativamente cerca de "intuition" y de "experience", pero relativamente lejos de "reason" o de "idea". (Ver comentarios al final del notebook).

# %%
# Graficar en 3D.
vecs, labels = reduce_dimensions(w2v_model, 3)
fig = px.scatter_3d(x=vecs[:MAX_WORDS ,0], y=vecs[:MAX_WORDS, 1], z=vecs[:MAX_WORDS, 2], text=labels[:MAX_WORDS])
fig.update_traces(marker_size=2)
fig.show(renderer='colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4fd8d2ad-4944-42e6-883a-b997b7e27ed7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fd8d2ad-4944-42e6-883a-b997b7e27ed7")) {                    Plotly.newPlot(                        "4fd8d2ad-4944-42e6-883a-b997b7e27ed7",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":2},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["the","of","to","in","is","and","a","which","that","it","as","be","this","not","we","but","for","all","by","an","are","with","reason","from","or","its","only","i","can","conception","our","must","experience","pure","time","object","conceptions","have","if","understanding","on","no","other","these","at","may","itself","intuition","they","\u00e0","cannot","possible","empirical","priori","existence","phenomena","us","cognition","transcendental","so","given","has","objects","any","one","therefore","unity","being","such","nature","their","merely","without","things","necessary","relation","them","conditions","upon","thus","principles","means","there","space","would","consequently","world","principle","same","than","do","general","possibility","mere","condition","idea","case","series","nothing","because"],"x":[9.003386497497559,9.318168640136719,108.45092010498047,-196.8259735107422,6.666553020477295,13.306609153747559,9.872483253479004,11.177597999572754,-0.49359795451164246,6.978650093078613,20.088552474975586,7.828846454620361,4.51915979385376,14.454907417297363,7.929524898529053,37.56764221191406,12.141979217529297,31.93708610534668,41.80276870727539,7.427115440368652,42.592041015625,35.327186584472656,33.10242462158203,38.892982482910156,46.97845458984375,53.041107177734375,32.9174690246582,26.54932403564453,51.351226806640625,34.746864318847656,53.38226318359375,48.137413024902344,26.933914184570312,39.0471305847168,40.41690444946289,33.96603775024414,42.40250015258789,-8.401305198669434,45.499603271484375,47.42053985595703,37.72021484375,40.92623519897461,34.930946350097656,41.67619705200195,61.874691009521484,30.913904190063477,36.52446365356445,33.649471282958984,47.89658737182617,46.58784103393555,48.49288558959961,37.241607666015625,55.39271926879883,47.25911331176758,22.247591018676758,29.45539093017578,37.2083625793457,46.875640869140625,52.374114990234375,30.064346313476562,31.470815658569336,59.547035217285156,28.55948829650879,-0.421932190656662,18.483583450317383,50.46921157836914,27.461952209472656,8.650801658630371,27.313074111938477,29.135847091674805,-20.994409561157227,27.11952018737793,32.56238555908203,24.822900772094727,22.045433044433594,44.16315841674805,41.56103515625,48.02312088012695,1.8471509218215942,48.5390625,60.12561798095703,45.588565826416016,40.30888748168945,39.3165397644043,36.61861801147461,40.245445251464844,35.01451873779297,28.656543731689453,55.32941818237305,61.54001998901367,50.26884078979492,46.7916145324707,42.98556900024414,4.5382609367370605,44.26082229614258,33.31919479370117,49.59230041503906,44.433189392089844,50.695953369140625,24.854427337646484],"y":[-2.392967939376831,-4.153751850128174,-3.012305736541748,-99.12000274658203,-5.364832878112793,-2.4143965244293213,6.351014614105225,1.6416481733322144,-0.1826716512441635,1.6859714984893799,31.093690872192383,6.749466896057129,-1.7964870929718018,2.995833158493042,1.3416625261306763,14.632532119750977,-1.9168769121170044,10.52782917022705,-10.26320743560791,14.225419998168945,16.405508041381836,17.896320343017578,-22.200057983398438,-18.207393646240234,13.594776153564453,-5.430761337280273,23.8685340881 ...

# %%
# Salvar vectores como .tsv para poder visualizarlos en herramientas como http://projector.tensorflow.org/.
vectors = np.asarray(w2v_model.wv.vectors)
labels = list(w2v_model.wv.index_to_key)
np.savetxt('vectors.tsv', vectors, delimiter='\t')
with open('labels.tsv', 'w') as fp:
    for item in labels:
        fp.write('%s\n' % item)

# %% [markdown]
# ### 6 - Preprocesamiento con NLTK

# %%
krv_str = ''
for _, row in krv_df[:None].iterrows():
    krv_str += row[0]

# Imprimir el texto completo antes del preprocesamiento.
print('Crítica de la Razón Pura antes del preprocesamiento:', krv_str)

stop_words = set(stopwords.words('english'))
sentences = sent_tokenize(krv_str.lower())
lemmatizer = WordNetLemmatizer()
tokenizer = RegexpTokenizer(r'\w+')
lemmatized_sentences = []
for sentence in sentences:
    tokens = tokenizer.tokenize(sentence.lower())
    filtered_tokens = [token for token in tokens if token not in stop_words]
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    lemmatized_sentence = ' '.join(lemmatized_tokens)
    lemmatized_sentences.append(lemmatized_sentence)

# Construir un dataframe con el texto preprocesado.
krv_df = pd.DataFrame(lemmatized_sentences, columns=['document'])

# Imprimir el texto completo después del preprocesamiento.
print('Crítica de la Razón Pura después del preprocesamiento:', ' '.join(krv_df['document']))
# Out:
# Crítica de la Razón Pura antes del preprocesamiento: This ebook is for the use of anyone anywhere in the United States andmost other parts of the world at no cost and with almost no restrictionswhatsoever. You may copy it, give it away or re-use it under the termsof the Project Gutenberg License included with this ebook or onlineat www.gutenberg.org. If you are not located in the United States,you will have to check the laws of the country where you are locatedbefore using this eBook.Title: The Critique of Pure ReasonAuthor: Immanuel KantTranslator: J. M. D. MeiklejohnRelease date: July 1, 2003 [eBook #4280]                Most recently updated: July 26, 2021Language: EnglishCredits: Charles Aldarondo and David Widger*** START OF THE PROJECT GUTENBERG EBOOK THE CRITIQUE OF PURE REASON ***[Illustration]The Critique of Pure ReasonBy Immanuel KantTranslated by J. M. D. MeiklejohnContents Preface to the First Edition (1781) Preface to the Second Edition (1787) Introduction I. Of the difference between Pure and Empirical Knowledge II. The Human Intellect, even in an Unphilosophical State, is in Possession of Certain Cognitions “à priori”. III. Philosophy stands in need of a Science which shall Determine the Possibility, Principles, and Extent of Human Knowledge “à priori” IV. Of the Difference Between Analytical and Synthetical Judgements. V. In all Theoretical Sciences of Reason, Synthetical Judgements “à priori” are contained as Principles. VI. The Universal Problem of Pure Reason. VII. Idea and Division of a Particular Science, under the Name of a Critique of Pure Reason. I. Transcendental Doctrine of Elements First Part—TRANSCENDENTAL ÆSTHETIC § 1. Introductory SECTION I. OF SPACE § 2. Metaphysical Exposition of this Conception. § 3. Transcendental Exposition of the Conception of Space. § 4. Conclusions from the foregoing Conceptions. SECTION II. OF TIME § 5. Metaphysical Exposition of this Conception. § 6. Transcendental Exposition of the Conception of Time. § 7. Conclusions from the above Conceptions. § 8. Elucidation. § 9. General Remarks on Transcendental Æsthetic. § 10. Conclusion of the Transcendental Æsthetic. Second Part—TRANSCENDENTAL LOGIC Introduction. Idea of a Transcendental Logic I. Of Logic in General II. Of Transcendental Logic III. Of the Division of General Logic into Analytic and Dialectic IV. Of the Division of Transcendental Logic into Transcendental Analytic and Dialectic FIRST DIVISION—TRANSCENDENTAL ANALYTIC BOOK I. Analytic of Conceptions. § 2 Chapter I. Of the Transcendental Clue to the Discovery of all Pure Conceptions of the Understanding Introductory § 3 Section I. Of the Logical Use of the Understanding in General. § 4 Section II. Of the Logical Function of the Understanding in Judgements. § 5 Section III. Of the Pure Conceptions of the Understanding, or Categories. § 6 Chapter II. Of the Deduction of the Pure Conception of the Understanding Section I. Of the Principles of a Transcendental Deduction in general § 9 Transition to the Transcendental Deduction of the Categories. § 10 Section II Transcendental Deduction of the pure Conceptions of the Understanding. Of the Possibility of a Conjunction of the manifold representations given by Sense. § 11. Of the Originally Synthetical Unity of Apperception. § 12 The Principle of the Synthetical Unity of Apperception is the highest Principle of all exercise of the Understanding. § 13 What Objective Unity of Self-consciousness is. § 14 The Logical Form of all Judgements consists in the Objective Unity of Apperception of the Conceptions contained therein. § 15 All Sensuous Intuitions are subject to the Categories, as Conditions under which alone the manifold Content of them can be united in one Consciousness. § 16 Observation. § 17 In Cognition, its Application to Objects of Experience is the only legitimate use of the Category. § 18 Of the Application of the Categories to Objects of the Senses in general. § 20 Transcendental Deduction of the universally pos ...
# Crítica de la Razón Pura después del preprocesamiento: ebook use anyone anywhere united state andmost part world cost almost restrictionswhatsoever may copy give away use termsof project gutenberg license included ebook onlineat www gutenberg org located united state check law country locatedbefore using ebook title critique pure reasonauthor immanuel kanttranslator j meiklejohnrelease date july 1 2003 ebook 4280 recently updated july 26 2021language englishcredits charles aldarondo david widger start project gutenberg ebook critique pure reason illustration critique pure reasonby immanuel kanttranslated j meiklejohncontents preface first edition 1781 preface second edition 1787 introduction difference pure empirical knowledge ii human intellect even unphilosophical state possession certain cognition à priori iii philosophy stand need science shall determine possibility principle extent human knowledge à priori iv difference analytical synthetical judgement v theoretical science reason synthetical judgement à priori contained principle vi universal problem pure reason vii idea division particular science name critique pure reason transcendental doctrine element first part transcendental æsthetic 1 introductory section space 2 metaphysical exposition conception 3 transcendental exposition conception space 4 conclusion foregoing conception section ii time 5 metaphysical exposition conception 6 transcendental exposition conception time 7 conclusion conception 8 elucidation 9 general remark transcendental æsthetic 10 conclusion transcendental æsthetic second part transcendental logic introduction idea transcendental logic logic general ii transcendental logic iii division general logic analytic dialectic iv division transcendental logic transcendental analytic dialectic first division transcendental analytic book analytic conception 2 chapter transcendental clue discovery pure conception understanding introductory 3 section logical use understanding general 4 section ii logical function understanding judgement 5 section iii pure conception understanding category 6 chapter ii deduction pure conception understanding section principle transcendental deduction general 9 transition transcendental deduction category 10 section ii transcendental deduction pure conception understanding possibility conjunction manifold representation given sense 11 originally synthetical unity apperception 12 principle synthetical unity apperception highest principle exercise understanding 13 objective unity self consciousness 14 logical form judgement consists objective unity apperception conception contained therein 15 sensuous intuition subject category condition alone manifold content united one consciousness 16 observation 17 cognition application object experience legitimate use category 18 application category object sens general 20 transcendental deduction universally possible employment experience pure conception understanding 22 result deduction conception understanding 23 book ii analytic principle introduction transcendental faculty judgement general transcendental doctrine faculty judgement analytic principle chapter schematism pure conception understanding chapter ii system principle pure understanding section supreme principle analytical judgement section ii supreme principle synthetical judgement section iii systematic representation synthetical principle pure understanding chapter iii ground division object phenomenon noumenon appendix second division transcendental logic transcendental dialectic introduction transcendental illusory appearance ii pure reason seat transcendental illusory appearance transcendental dialectic book conception pure reason section idea general section ii transcendental idea section iii system transcendental idea transcendental dialectic book ii dialectical procedure pure reason chapter paralogism pure reason chapter ii antinomy pure reason section system cosmological idea section ii antithetic pure reason section ...

# %%
sentence_tokens = [sentence.split() for sentence in lemmatized_sentences]

# Explorar algunos de los tokens obtenidos.
print(f'Algunos tokens obtenidos: ', sentence_tokens[:10])

# Explorar el DF generado.
krv_df.head()
# Out:
# Algunos tokens obtenidos:  [['ebook', 'use', 'anyone', 'anywhere', 'united', 'state', 'andmost', 'part', 'world', 'cost', 'almost', 'restrictionswhatsoever'], ['may', 'copy', 'give', 'away', 'use', 'termsof', 'project', 'gutenberg', 'license', 'included', 'ebook', 'onlineat', 'www', 'gutenberg', 'org'], ['located', 'united', 'state', 'check', 'law', 'country', 'locatedbefore', 'using', 'ebook', 'title', 'critique', 'pure', 'reasonauthor', 'immanuel', 'kanttranslator', 'j', 'meiklejohnrelease', 'date', 'july', '1', '2003', 'ebook', '4280', 'recently', 'updated', 'july', '26', '2021language', 'englishcredits', 'charles', 'aldarondo', 'david', 'widger', 'start', 'project', 'gutenberg', 'ebook', 'critique', 'pure', 'reason', 'illustration', 'critique', 'pure', 'reasonby', 'immanuel', 'kanttranslated', 'j', 'meiklejohncontents', 'preface', 'first', 'edition', '1781', 'preface', 'second', 'edition', '1787', 'introduction', 'difference', 'pure', 'empirical', 'knowledge', 'ii'], ['human', 'intellect', 'even', 'unphilosophical', 'state', 'possession', 'certain', 'cognition', 'à', 'priori'], ['iii'], ['philosophy', 'stand', 'need', 'science', 'shall', 'determine', 'possibility', 'principle', 'extent', 'human', 'knowledge', 'à', 'priori', 'iv'], ['difference', 'analytical', 'synthetical', 'judgement'], ['v', 'theoretical', 'science', 'reason', 'synthetical', 'judgement', 'à', 'priori', 'contained', 'principle'], ['vi'], ['universal', 'problem', 'pure', 'reason']]
#                                             document
# 0  ebook use anyone anywhere united state andmost...
# 1  may copy give away use termsof project gutenbe...
# 2  located united state check law country located...
# 3  human intellect even unphilosophical state pos...
# 4                                                iii

# %%
w2v_model = Word2Vec(min_count=5,
                     window=2,
                     vector_size=300,
                     negative=20,
                     workers=1,
                     sg=1) # modelo 0:CBOW  1:skipgram

# Obtener el vocabulario con los tokens
w2v_model.build_vocab(sentence_tokens)

# Cantidad de filas/documentos encontradas en el corpus.
print('Cantidad de documentos en el corpus:', w2v_model.corpus_count)

# Cantidad de palabras encontradas en el corpus.
print('Cantidad de palabras distintas en el corpus:', len(w2v_model.wv.index_to_key))
# Out:
# Cantidad de documentos en el corpus: 4597
# Cantidad de palabras distintas en el corpus: 2244

# %%
lemmatized_sentences_tokenized = [sentence.split() for sentence in lemmatized_sentences]

w2v_model.train(sentence_tokens,
                total_examples=w2v_model.corpus_count,
                epochs=100,
                compute_loss=True,
                callbacks=[callback()])
# Out:
# Loss after epoch 0: 1031883.6875
# Loss after epoch 5: 570848.75
# Loss after epoch 10: 507934.5
# Loss after epoch 15: 452442.0
# Loss after epoch 20: 427216.0
# Loss after epoch 25: 411965.0
# Loss after epoch 30: 401054.0
# Loss after epoch 35: 354534.0
# Loss after epoch 40: 347492.0
# Loss after epoch 45: 343866.0
# Loss after epoch 50: 337728.0
# Loss after epoch 55: 333928.0
# Loss after epoch 60: 330476.0
# Loss after epoch 65: 326442.0
# Loss after epoch 70: 323490.0
# Loss after epoch 75: 320692.0
# Loss after epoch 80: 316272.0
# Loss after epoch 85: 270346.0
# Loss after epoch 90: 261612.0
# Loss after epoch 95: 258544.0
# (6984507, 9865400)

# %%
for word in ['space', 'time', 'reason', 'priori', 'posteriori', 'intuition', 'category', 'metaphysic', 'sensibility', 'necessary']:
    print_most_similars(w2v_model, word, 10)
# Out:
# Palabras más similares a space:
# Palabra: filled. Similitud: 0.40263715386390686
# Palabra: spaceand. Similitud: 0.36557766795158386
# Palabra: theinternal. Similitud: 0.33013850450515747
# Palabra: ready. Similitud: 0.32094302773475647
# Palabra: portion. Similitud: 0.30420321226119995
# Palabra: assign. Similitud: 0.30116844177246094
# Palabra: intime. Similitud: 0.2974775433540344
# Palabra: whatsoever. Similitud: 0.2958919107913971
# Palabra: ordinated. Similitud: 0.29471978545188904
# Palabra: theseprinciples. Similitud: 0.2922725975513458
#
#
# Palabras más similares a time:
# Palabra: past. Similitud: 0.3167022168636322
# Palabra: duration. Similitud: 0.30187931656837463
# Palabra: filled. Similitud: 0.29426345229148865
# Palabra: intellect. Similitud: 0.28991350531578064
# Palabra: continuum. Similitud: 0.28987231850624084
# Palabra: asynthesis. Similitud: 0.2862904369831085
# Palabra: change. Similitud: 0.28369033336639404
# Palabra: successive. Similitud: 0.2814454138278961
# Palabra: distant. Similitud: 0.28053605556488037
# Palabra: aswell. Similitud: 0.27804914116859436
#
#
# Palabras más similares a reason:
# Palabra: polemic. Similitud: 0.3127090036869049
# Palabra: fruitless. Similitud: 0.30900582671165466
# Palabra: advancement. Similitud: 0.3046243488788605
# Palabra: mustalways. Similitud: 0.30393311381340027
# Palabra: overstep. Similitud: 0.2931598424911499
# Palabra: purereason. Similitud: 0.2831778824329376
# Palabra: fate. Similitud: 0.2822979688644409
# Palabra: promotive. Similitud: 0.28188556432724
# Palabra: ofreason. Similitud: 0.27813056111335754
# Palabra: structure. Similitud: 0.2696145176887512
#
#
# Palabras más similares a priori:
# Palabra: à. Similitud: 0.7359120845794678
# Palabra: posteriori. Similitud: 0.37130874395370483
# Palabra: prioriintuition. Similitud: 0.3604947328567505
# Palabra: whichalone. Similitud: 0.33598029613494873
# Palabra: àposteriori. Similitud: 0.32610660791397095
# Palabra: àpriori. Similitud: 0.3233603835105896
# Palabra: antecedently. Similitud: 0.3185594975948334
# Palabra: vi. Similitud: 0.3061077892780304
# Palabra: asynthesis. Similitud: 0.30039510130882263
# Palabra: arrangement. Similitud: 0.29081082344055176
#
#
# Palabras más similares a posteriori:
# Palabra: prioriintuition. Similitud: 0.4545964300632477
# Palabra: antecedently. Similitud: 0.43385446071624756
# Palabra: whichalone. Similitud: 0.4151673913002014
# Palabra: andwithout. Similitud: 0.3904040455818176
# Palabra: orthe. Similitud: 0.3885153830051422
# Palabra: vi. Similitud: 0.3876589834690094
# Palabra: thetruth. Similitud: 0.3818620443344116
# Palabra: theconstruction. Similitud: 0.38088738918304443
# Palabra: atall. Similitud: 0.37664833664894104
# Palabra: begiven. Similitud: 0.37589791417121887
#
#
# Palabras más similares a intuition:
# Palabra: syntheticalunity. Similitud: 0.33478665351867676
# Palabra: whichalone. Similitud: 0.3342314660549164
# Palabra: sensuous. Similitud: 0.3293952941894531
# Palabra: themanifold. Similitud: 0.328168123960495
# Palabra: 16. Similitud: 0.32611021399497986
# Palabra: manifoldin. Similitud: 0.31531158089637756
# Palabra: anintuition. Similitud: 0.3095444142818451
# Palabra: empiricalintuition. Similitud: 0.3091799318790436
# Palabra: impression. Similitud: 0.30785778164863586
# Palabra: theintuition. Similitud: 0.30584925413131714
#
#
# Palabras más similares a category:
# Palabra: prioriconceptions. Similitud: 0.33160415291786194
# Palabra: theschema. Similitud: 0.3286534547805786
# Palabra: nihil. Similitud: 0.3140697777271271
# Palabra: subsumption. Similitud: 0.3138301968574524
# Palabra: theprinciples. Similitud: 0.3117041289806366
# Palabra: geometrical. Similitud: 0.30724290013313293
# Palabra: applying. Similitud: 0.306333065032959
# Palabra: thematter. Similitud: 0.30519405007362366
# Palabra: schematism. Similitud: 0.30107346177101135
# Palabra: thepure. Similitud: 0.2995929718017578
#
#
# Palabras más similares a metaphysic:
# Palabra: especially. Similitud: 0.3989962041378021
# Palabra: ethic. Similitud: 0.38106802105903625
# Palabra: physiology. Similitud: 0.3787044286727905
# Palabra: contradistinction. Similitud: 0.37453028559684753
# Palabra: analytic. Similitud: 0.3695005178451538
# Palabra: pretended. Similitud: 0.36456623673439026
# Palabra: intheir. Similitud: 0.36395740509033203
# Palabra: exposed. Similitud: 0.36099034547805786
# Palabra: rationalis. Similitud: 0.3546910583972931
# Palabra: apodeictically. Similitud: 0.3535960018634796
#
#
# Palabras más similares a sensibility:
# Palabra: totime. Similitud: 0.36139604449272156
# Palabra: consciousnessof. Similitud: 0.32235974073410034
# Palabra: receptivity. Similitud: 0.3159010410308838
# Palabra: restricted. Similitud: 0.3144983649253845
# Palabra: andwithout. Similitud: 0.3118041455745697
# Palabra: theinternal. Similitud: 0.3117702007293701
# Palabra: receiving. Similitud: 0.30521470308303833
# Palabra: anyempirical. Similitud: 0.2976260483264923
# Palabra: containing. Similitud: 0.2976018786430359
# Palabra: 20. Similitud: 0.29633066058158875
#
#
# Palabras más similares a necessary:
# Palabra: absolutely. Similitud: 0.3317166566848755
# Palabra: sensuously. Similitud: 0.32973697781562805
# Palabra: necessarybeing. Similitud: 0.3215601444244385
# Palabra: anecessary. Similitud: 0.3205604553222656
# Palabra: happened. Similitud: 0.31163668632507324
# Palabra: causeof. Similitud: 0.2982686161994934
# Palabra: unconditionally. Similitud: 0.2936705946922302
# Palabra: recognized. Similitud: 0.2936386466026306
# Palabra: theseries. Similitud: 0.2917332649230957
# Palabra: ofapperception. Similitud: 0.2859531044960022

# %% [markdown]
# En general, la primera forma de tokenización sin haber usado NLTK, aunque más simple, dio resultados más interesantes de cara a analizar cercanía semántica entre términos filosóficos.

# %% [markdown]
# ### 7 - Comentarios finales

# %% [markdown]
# - Mediante el entrenamiento de embeddings con el modelo Skip-gram, se obtuvieron representaciones vectoriales de palabras tomadas de la obra Crítica de la Razón Pura. Se planteó como objetivo el observar si los vectores densos obtenidos lograban captar la cercanía semántica que algunos términos de esta obra guardan unos con otros.
# - Más allá de lo que podría considerarse esperable, como que junto con "time" aparezca "past", es más interesante notar cómo junto a aquella palabra figura "intuited" entre las más similares. Asimismo, junto a "space" están "sensibility" e "intuition".
# Esto es destacable porque capta un aspecto muy específico de la filosofía kantiana: Que, según este pensador, espacio y tiempo son "intuiciones puras" o "formas puras de la sensibilidad", en lugar de entidades físicas independientes del sujeto.
# - Un posible problema con los vectores obtenidos es que hay términos que, aunque con frecuencia figuran juntos en el texto, tienen significados excluyentes. Por ejemplo "priori" y "posteriori" están cercanos en el espacio obtenido, a pesar de que un conocimiento es a priori si y sólo si no es a posteriori.
# - El análisis de los términos menos similares no aporta tanta información como el anterior. La mayoría de las palabras menos semejantes tienen escasa o nula relevancia filosófica.
